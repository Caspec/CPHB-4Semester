# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename = './KoreanConflict.csv'
bef_stats_df = pd.read_csv(filename)
dd = bef_stats_df.as_matrix()


# 4509 MARINE CORPS (12%)
# 29856 ARMY (82%)
# 1552 AIR FORCE (4%)
# 657 NAVY (2%)
# 36574 TOTAL (100%)


# Q1: How many soldiers entered from a marine corps branch?

mask = (dd[:,3] == 'MARINE CORPS')
np.sum(mask)

# 4509 MARINE CORPS

# Data to plot
labels = 'MARINE CORPS', 'ARMY', 'AIR FORCE', 'NAVY'
sizes = [4509, 29856, 1552, 657]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Q1: How many soldiers entered from a marine corps branch?', fontsize=20)  
plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(10,10) 
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename = './KoreanConflict.csv'
bef_stats_df = pd.read_csv(filename)
dd = bef_stats_df.as_matrix()


# 23973 ACTIVE - REGULAR (66%)
# 7512 SELECTED SERVICE (21%)
# 5089 ACTIVE - GUARD/RESERVE (14%)
# 36574 TOTAL (100%)


# Q2: Which enrollment was the most common?

mask = (dd[:,2] == 'ACTIVE - REGULAR')
np.sum(mask)

# 23973 ACTIVE - REGULAR


# Data to plot
labels = 'ACTIVE - REGULAR', 'SELECTED SERVICE', 'ACTIVE - GUARD/RESERVE'
sizes = [23973, 7512, 5089]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=360)
plt.title('Q2: Which enrollment was the most common?', fontsize=20) 
plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(10,10) 
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename = './KoreanConflict.csv'
bef_stats_df = pd.read_csv(filename)
dd = bef_stats_df.as_matrix()


# 29405 WHITE (81%)
# 3258 AMERICAN INDIAN/ALASKA NATIVE (9%)
# 3130 BLACK OR AFRICAN AMERICAN (9%)
# 781 ASIAN LORT (1%)
# 36574 TOTAL (100%)


# Q3: Was there an ethnicity majority throughout the war - If so, which?

mask = (dd[:,15] == "WHITE")
np.sum(mask)

# 29405 WHITE 

# Data to plot
labels = 'WHITE', 'AMERICAN INDIAN/ALASKA NATIVE', 'BLACK OR AFRICAN AMERICAN', 'ASIAN BU...'
sizes = [29405, 3258, 3130, 781]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=360)
plt.title('Q3: Was there an ethnicity majority throughout the war - If so, which?', fontsize=20) 
plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(10,10) 
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename = './KoreanConflict.csv'
bef_stats_df = pd.read_csv(filename)
dd = bef_stats_df.as_matrix()


# KILLED IN ACTION (62%)
# DECLARED DEAD (20%)
# DIED OF WOUNDS (6%)
# ACCIDENT (2%)
# DECEASED (1%)
# OTHER (9%)

# 1336 38 INF 2 DIV
# 1215 9 INF 2 DIV
# 1139 19 INF 24 DIV
# 3690 TOTAL

# Q4: Which division had the most casualties?

mask = (dd[:,18] == "19 INF 24 DIV") & (dd[:,23] == "KILLED IN ACTION") 
np.sum(mask)



# Data to plot
labels = '38 INF 2 DIV', '9 INF 2 DIV', '19 INF 24 DIV'
sizes = [1336, 1215, 1139]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=360)
plt.title('Q4: Which division had the most casualties?', fontsize=20) 
plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(10,10) 
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

filename = './KoreanConflict.csv'
bef_stats_df = pd.read_csv(filename)
dd = bef_stats_df.as_matrix()


# 1677 CALIFORNIA (7%)
# 1561 PENNSYLVANIA (7%)
# 1474 NEW YORK (7%)
# 1203 OHIO (5%)



# Q5: Which Home state suffered the most losses?

mask = (dd[:,13] == "CALIFORNIA") & (dd[:,23] == "KILLED IN ACTION") 
np.sum(mask)


# Data to plot
labels = 'CALIFORNIA', 'PENNSYLVANIA', 'NEW YORK', 'OHIO'
sizes = [1677, 1561, 1474, 1203]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=360)
plt.title('Q5: Which Home state suffered the most losses?', fontsize=20) 
plt.axis('equal')
fig = plt.gcf()
fig.set_size_inches(10,10) 
plt.show()
